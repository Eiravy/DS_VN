# %%
# %load_ext autoreload
# %autoreload 2
import os
import sys
import time
import numpy as np
from Shapley import ShapNN
from DShap import DShap
import matplotlib.pyplot as plt
import sklearn
from shap_utils import *
# %matplotlib inline
MEM_DIR = './'
problem, model = 'classification', 'logistic'
hidden_units = [] # Empty list in the case of logistic regression.
train_size = 2000
d, difficulty = 50, 1
num_classes = 2
tol = 0.03
target_accuracy = 0.7
important_dims = 5
clf = return_model(model, solver='liblinear', hidden_units=tuple(hidden_units))
_param = 1.0
for _ in range(100):
    X_raw = np.random.multivariate_normal(mean=np.zeros(d), cov = np.eye(d), 
                                          size=train_size + 5000)
    _, y_raw, _, _ = label_generator(
        problem, X_raw, param = _param,  difficulty = difficulty, important=important_dims)
    clf.fit(X_raw[:train_size], y_raw[:train_size])
    test_acc = clf.score(X_raw[train_size:], y_raw[train_size:])
    if test_acc > target_accuracy:
        break
    _param *= 1.1
print('Performance using the whole training set = {0:.2f}'.format(test_acc))
X, y = X_raw[:train_size], y_raw[:train_size]
X_test, y_test = X_raw[train_size:], y_raw[train_size:]
model = 'logistic'
problem = 'classification'
num_test = 1000
directory = './temp'
dshap = DShap(X, y, X_test, y_test, num_test, 
              sources=None, 
              sample_weight=None,
              model_family=model, 
              metric='accuracy',
              overwrite=True,
              directory=directory, seed=0)
dshap.run(100, 0.1)
# Out:
# 2026-04-10 13:26:35.565946: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-04-10 13:26:36.118592: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# WARNING:tensorflow:From /home/philipslinux/anaconda3/lib/python3.10/site-packages/tensorflow/python/compat/v2_compat.py:98: disable_resource_variables (from tensorflow.python.ops.resource_variables_toggle) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# Performance using the whole training set = 0.70
# Starting LOO score calculations!
# LOO values calculated!
# WARNING:tensorflow:From /home/philipslinux/anaconda3/lib/python3.10/site-packages/tensorflow/python/util/dispatch.py:1260: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# 2026-04-10 13:26:48.251030: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2026-04-10 13:26:48.251542: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2026-04-10 13:26:48.432105: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:388] MLIR V1 optimization pass is not enabled
# 2026-04-10 13:26:48.444563: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2026-04-10 13:26:48.862308: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2026-04-10 13:26:48.868867: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2026-04-10 13:26:49.250538: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2026-04-10 13:26:49.256990: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2026-04-10 13:26:49.619398: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2026-04-10 13:26:49.625913: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2026-04-10 13:26:50.006223: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2026-04-10 13:26:50.012500: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2026-04-10 13:26:50.358061: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2026-04-10 13:26:50.364296: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2026-04-10 13:26:50.712417: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2026-04-10 13:26:50.718872: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2026-04-10 13:26:51.077704: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2026-04-10 13:26:51.084177: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2026-04-10 13:26:51.442221: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2026-04-10 13:26:51.448542: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2026-04-10 13:26:51.868931: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2026-04-10 13:26:51.876106: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2026-04-10 13:26:52.244395: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2026-04-10 13:26:52.244509: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2026-04-10 13:26:52.280037: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2026-04-10 13:26:52.676587: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2026-04-10 13:26:52.682689: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2026-04-10 13:26:53.053631: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2026-04-10 13:26:53.060082: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2026-04-10 13:26:53.443390: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2026-04-10 13:26:53.449794: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2026-04-10 13:26:53.828162: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2026-04-10 13:26:53.834394: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2026-04-10 13:26:54.222853: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2026-04-10 13:26:54.229604: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2026-04-10 13:26:54.602223: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2026-04-10 13:26:54.608589: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2026-04-10 13:26:55.058218: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2026-04-10 13:26:55.066699: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2026-04-10 13:26:55.434244: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2026-04-10 13:26:55.441064: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2026-04-10 13:26:55.788362: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2026-04-10 13:26:55.795174: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2026-04-10 13:26:56.182464: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2026-04-10 13:26:56.182576: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2026-04-10 13:26:56.218879: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2026-04-10 13:26:56.603184: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2026-04-10 13:26:56.609745: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2026-04-10 13:26:56.968547: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2026-04-10 13:26:56.975187: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2026-04-10 13:26:57.318737: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2026-04-10 13:26:57.325421: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2026-04-10 13:26:57.669266: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2026-04-10 13:26:57.675880: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2026-04-10 13:26:58.038908: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2026-04-10 13:26:58.045385: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2026-04-10 13:26:58.403367: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2026-04-10 13:26:58.409888: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2026-04-10 13:26:58.765169: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2026-04-10 13:26:58.772085: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2026-04-10 13:26:59.136980: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2026-04-10 13:26:59.143454: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2026-04-10 13:26:59.536593: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2026-04-10 13:26:59.543444: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2026-04-10 13:26:59.948587: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2026-04-10 13:26:59.948788: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2026-04-10 13:26:59.985704: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2026-04-10 13:27:00.351687: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2026-04-10 13:27:00.357941: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2026-04-10 13:27:00.747023: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2026-04-10 13:27:00.753394: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2026-04-10 13:27:01.121873: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2026-04-10 13:27:01.128777: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2026-04-10 13:27:01.484247: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2026-04-10 13:27:01.491378: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2026-04-10 13:27:01.850028: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2026-04-10 13:27:01.857170: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2026-04-10 13:27:02.237295: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2026-04-10 13:27:02.244541: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2026-04-10 13:27:02.614176: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2026-04-10 13:27:02.621617: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2026-04-10 13:27:02.988940: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2026-04-10 13:27:02.995395: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2026-04-10 13:27:03.365480: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2026-04-10 13:27:03.372381: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2026-04-10 13:27:03.721776: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2026-04-10 13:27:03.721888: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2026-04-10 13:27:03.755192: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2026-04-10 13:27:04.116438: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2026-04-10 13:27:04.122701: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# ...
# 2026-04-10 15:40:20.632595: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2026-04-10 15:40:22.289646: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2026-04-10 15:40:22.298299: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2026-04-10 15:40:24.028226: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2026-04-10 15:40:24.038085: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2026-04-10 15:40:25.929217: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2026-04-10 15:40:25.938557: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2026-04-10 15:40:27.489812: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2026-04-10 15:40:27.499396: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 90 out of 100 G-Shapley iterations
# 2026-04-10 15:40:29.068388: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2026-04-10 15:40:29.077896: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2026-04-10 15:40:30.652202: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2026-04-10 15:40:30.661632: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2026-04-10 15:40:32.253774: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2026-04-10 15:40:32.263033: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2026-04-10 15:40:33.862317: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2026-04-10 15:40:33.871638: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2026-04-10 15:40:35.483374: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2026-04-10 15:40:35.492879: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2026-04-10 15:40:37.085951: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2026-04-10 15:40:37.095179: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2026-04-10 15:40:38.806847: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2026-04-10 15:40:38.815977: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2026-04-10 15:40:40.454782: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2026-04-10 15:40:40.463652: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2026-04-10 15:40:42.138164: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2026-04-10 15:40:42.147153: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2026-04-10 15:40:43.878721: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2026-04-10 15:40:43.888226: W tensorflow/c/c_api.cc:305] Operation '{name:'final/Db/Assign' id:24 op device:{requested: '', assigned: ''} def:{{{node final/Db/Assign}} = Assign[T=DT_FLOAT, _class=["loc:@final/Db"], _has_manual_control_dependencies=true, use_locking=true, validate_shape=true](final/Db, final/Db/Initializer/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 100 out of 100 G-Shapley iterations

# %%
len(dshap.vals_tmc)
# Out:
# 2000

# %%
from DShap import *
# %matplotlib inline
dshap.performance_plots_low_rev_add(
    [dshap.vals_tmc, dshap.vals_g, dshap.vals_loo],
    name='addition_analysis',
    num_plot_markers=20,  # Not used in addition mode but kept for compatibility
    sources=dshap.sources,
    add_steps=[0,50,100,150,200,250,300]
)
# Out:
# Test set size: 1000
# Baseline: 100 training samples → 70.0% accuracy
# Adding points: [0, 50, 100, 150, 200, 250, 300]
#
# Verifying baseline performance...
# Verified baseline accuracy: 0.6200 (62.00%)
#
# ==================================================
# Calculating for method 0...
# ==================================================
# Sorted 2000 training points by value (lowest first)
#
#   Adding 0 low-value points...
#     Training on 100 samples (100 baseline + 0 added)
#     Test accuracy: 0.6200 (62.00%)
#
#   Adding 50 low-value points...
#     Training on 147 samples (100 baseline + 50 added)
#     Test accuracy: 0.4860 (48.60%)
#
#   Adding 100 low-value points...
#     Training on 197 samples (100 baseline + 100 added)
#     Test accuracy: 0.4230 (42.30%)
#
#   Adding 150 low-value points...
#     Training on 245 samples (100 baseline + 150 added)
#     Test accuracy: 0.3780 (37.80%)
#
#   Adding 200 low-value points...
#     Training on 294 samples (100 baseline + 200 added)
#     Test accuracy: 0.3660 (36.60%)
#
#   Adding 250 low-value points...
#     Training on 340 samples (100 baseline + 250 added)
#     Test accuracy: 0.3540 (35.40%)
#
#   Adding 300 low-value points...
#     Training on 386 samples (100 baseline + 300 added)
#     Test accuracy: 0.3420 (34.20%)
#
# ==================================================
# Calculating for method 1...
# ==================================================
# Sorted 2000 training points by value (lowest first)
#
#   Adding 0 low-value points...
#     Training on 100 samples (100 baseline + 0 added)
#     Test accuracy: 0.6200 (62.00%)
#
#   Adding 50 low-value points...
#     Training on 148 samples (100 baseline + 50 added)
#     Test accuracy: 0.5290 (52.90%)
#
#   Adding 100 low-value points...
#     Training on 197 samples (100 baseline + 100 added)
#     Test accuracy: 0.4760 (47.60%)
#
#   Adding 150 low-value points...
#     Training on 244 samples (100 baseline + 150 added)
#     Test accuracy: 0.4820 (48.20%)
#
#   Adding 200 low-value points...
#     Training on 292 samples (100 baseline + 200 added)
#     Test accuracy: 0.4540 (45.40%)
#
#   Adding 250 low-value points...
#     Training on 341 samples (100 baseline + 250 added)
#     Test accuracy: 0.4530 (45.30%)
#
#   Adding 300 low-value points...
#     Training on 389 samples (100 baseline + 300 added)
#     Test accuracy: 0.4380 (43.80%)
#
# ==================================================
# Calculating for method 2...
# ==================================================
# Sorted 2000 training points by value (lowest first)
#
#   Adding 0 low-value points...
#     Training on 100 samples (100 baseline + 0 added)
#     Test accuracy: 0.6200 (62.00%)
#
#   Adding 50 low-value points...
#     Training on 150 samples (100 baseline + 50 added)
#     Test accuracy: 0.5810 (58.10%)
#
#   Adding 100 low-value points...
#     Training on 200 samples (100 baseline + 100 added)
#     Test accuracy: 0.5640 (56.40%)
#
#   Adding 150 low-value points...
#     Training on 250 samples (100 baseline + 150 added)
#     Test accuracy: 0.5840 (58.40%)
#
#   Adding 200 low-value points...
#     Training on 299 samples (100 baseline + 200 added)
#     Test accuracy: 0.5720 (57.20%)
#
#   Adding 250 low-value points...
#     Training on 343 samples (100 baseline + 250 added)
#     Test accuracy: 0.5660 (56.60%)
#
#   Adding 300 low-value points...
#     Training on 390 samples (100 baseline + 300 added)
#     Test accuracy: 0.5870 (58.70%)
#
# ==================================================
# Calculating random baseline...
# ==================================================
#   Trial 1/5
#   Trial 2/5
#   Trial 3/5
#   Trial 4/5
#   Trial 5/5
#
# ================================================================================
# PERFORMANCE TABLE (Accuracy %)
# ================================================================================
# Method               0 added      100        200        300        400        500
# --------------------------------------------------------------------------------
# TMC-Shapley          62.00%       62.00%     48.60%     42.30%     37.80%     36.60%
# G-Shapley            62.00%       62.00%     52.90%     47.60%     48.20%     45.40%
# LOO                  62.00%       62.00%     58.10%     56.40%     58.40%     57.20%
# Random (average)     62.00%       62.00%     62.90%     65.58%     66.22%     65.04%
# Random (std)         0.00%     0.00%    1.74%    0.52%    0.67%    0.50%
# ================================================================================
#
# ==================================================
# GENERATING PLOT...
# ==================================================
# ✓ Plot saved to ./temp/plots/addition_analysis_add_low_value.png
#
# ==================================================
# COMPLETE!
# ==================================================
# ([0, 0, 50, 100, 150, 200, 250, 300],
#  [[0.62, 0.62, 0.486, 0.423, 0.378, 0.366, 0.354, 0.342],
#   [0.62, 0.62, 0.529, 0.476, 0.482, 0.454, 0.453, 0.438],
#   [0.62, 0.62, 0.581, 0.564, 0.584, 0.572, 0.566, 0.587]],
#  array([0.62  , 0.62  , 0.629 , 0.6558, 0.6622, 0.6504, 0.6652, 0.6724]))
